# %% [markdown]
# <a href="https://www.kaggle.com/code/averma111/pytorch-auto-pytorch?scriptVersionId=128587167" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip install autoPyTorch
# Out:
# Collecting autoPyTorch
#   Downloading autoPyTorch-0.2.1-py3-none-any.whl (711 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 711.9/711.9 kB 10.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy>=1.7 in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (1.9.3)
# Requirement already satisfied: torch>=1.10.1 in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (2.0.0+cpu)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (0.15.1+cpu)
# Collecting flaky
#   Downloading flaky-3.7.0-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (2.11.2)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (3.3.2)
# Requirement already satisfied: distributed>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (2023.4.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (1.5.3)
# Collecting smac>=1.2
#   Downloading smac-2.0.0.tar.gz (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.9/144.9 kB 13.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (0.9.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (1.23.5)
# Collecting pynisher>=0.6.3
#   Downloading pynisher-1.0.5.tar.gz (28 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: imgaug>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (0.4.0)
# Collecting pyrfr<0.9,>=0.7
#   Downloading pyrfr-0.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 57.2 MB/s eta 0:00:0000:0100:01
# Collecting lockfile
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Collecting ConfigSpace>=0.5.0
#   Downloading ConfigSpace-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 81.6 MB/s eta 0:00:00:00:01
# Requirement already satisfied: catboost in /opt/conda/lib/python3.10/site-packages (from autoPyTorch) (1.1.1)
# Collecting scikit-learn<0.25.0,>=0.24.0
#   Downloading scikit-learn-0.24.2.tar.gz (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 78.8 MB/s eta 0:00:00:00:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... \

# %%
from autoPyTorch.api.tabular_classification import TabularClassificationTask

# data and metric imports
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics
X, y = sklearn.datasets.load_digits(return_X_y=True)
X_train, X_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(X, y, random_state=1)

# initialise Auto-PyTorch api
api = TabularClassificationTask()

# Search for an ensemble of machine learning algorithms
api.search(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    optimize_metric='accuracy',
    total_walltime_limit=300,
    func_eval_time_limit_secs=50
)

# Calculate test accuracy
y_pred = api.predict(X_test)
score = api.score(y_pred, y_test)
print("Accuracy score", score)
