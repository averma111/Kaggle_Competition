# %%
import pathlib
import tensorflow as tf
import os
import PIL
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

# %%
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 [==============================] - 9s 0us/step

# %%
data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
print(os.listdir(data_dir))
# Out:
# ['roses', 'dandelion', 'sunflowers', 'LICENSE.txt', 'daisy', 'tulips']

# %%
roses = list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
daisy = list(data_dir.glob('daisy/*'))
PIL.Image.open(str(daisy[2]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
valid_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
  for i in range(12):
    ax = plt.subplot(3, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
num_classes = len(class_names)
model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes,activation='softmax')
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,989,285
# Trainable params: 3,989,285
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=15
history = model.fit(
  train_ds,
  validation_data=valid_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# /opt/conda/lib/python3.7/site-packages/keras/backend.py:5586: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits, "Softmax", "sparse_categorical_crossentropy"
# 92/92 [==============================] - 64s 678ms/step - loss: 1.4242 - accuracy: 0.4278 - val_loss: 1.1002 - val_accuracy: 0.5354
# Epoch 2/15
# 92/92 [==============================] - 62s 670ms/step - loss: 1.0019 - accuracy: 0.6052 - val_loss: 1.0383 - val_accuracy: 0.5681
# Epoch 3/15
# 92/92 [==============================] - 62s 672ms/step - loss: 0.8546 - accuracy: 0.6822 - val_loss: 0.9573 - val_accuracy: 0.6294
# Epoch 4/15
# 92/92 [==============================] - 62s 667ms/step - loss: 0.6682 - accuracy: 0.7544 - val_loss: 1.0155 - val_accuracy: 0.6213
# Epoch 5/15
# 92/92 [==============================] - 61s 665ms/step - loss: 0.4413 - accuracy: 0.8423 - val_loss: 1.3179 - val_accuracy: 0.6049
# Epoch 6/15
# 92/92 [==============================] - 62s 672ms/step - loss: 0.2827 - accuracy: 0.9016 - val_loss: 1.5378 - val_accuracy: 0.5872
# Epoch 7/15
# 92/92 [==============================] - 62s 672ms/step - loss: 0.1739 - accuracy: 0.9455 - val_loss: 1.6416 - val_accuracy: 0.6144
# Epoch 8/15
# 92/92 [==============================] - 62s 669ms/step - loss: 0.1199 - accuracy: 0.9656 - val_loss: 1.8733 - val_accuracy: 0.6158
# Epoch 9/15
# 92/92 [==============================] - 63s 684ms/step - loss: 0.0700 - accuracy: 0.9802 - val_loss: 2.0913 - val_accuracy: 0.6158
# Epoch 10/15
# 92/92 [==============================] - 63s 686ms/step - loss: 0.0750 - accuracy: 0.9775 - val_loss: 2.2455 - val_accuracy: 0.5858
# Epoch 11/15
# 92/92 [==============================] - 64s 692ms/step - loss: 0.0738 - accuracy: 0.9796 - val_loss: 2.1486 - val_accuracy: 0.6076
# Epoch 12/15
# 92/92 [==============================] - 63s 678ms/step - loss: 0.0558 - accuracy: 0.9860 - val_loss: 2.3732 - val_accuracy: 0.6008
# Epoch 13/15
# 92/92 [==============================] - 62s 675ms/step - loss: 0.0542 - accuracy: 0.9854 - val_loss: 2.2597 - val_accuracy: 0.6158
# Epoch 14/15
# 92/92 [==============================] - 63s 678ms/step - loss: 0.0716 - accuracy: 0.9772 - val_loss: 2.2673 - val_accuracy: 0.6090
# Epoch 15/15
# 92/92 [==============================] - 63s 683ms/step - loss: 0.0222 - accuracy: 0.9946 - val_loss: 2.4493 - val_accuracy: 0.6049

# %%
def predict_input_image(img):
  img_4d=img.reshape(-1,180,180,3)
  prediction=model.predict(img_4d)[0]
  return {class_names[i]: float(prediction[i]) for i in range(5)}

# %%
import gradio as gr

# %%
image = gr.inputs.Image(shape=(180,180))
label = gr.outputs.Label(num_top_classes=5)
# Out:
# /opt/conda/lib/python3.7/site-packages/gradio/inputs.py:258: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /opt/conda/lib/python3.7/site-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /opt/conda/lib/python3.7/site-packages/gradio/outputs.py:198: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# /opt/conda/lib/python3.7/site-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)

# %%
gr.Interface(fn=predict_input_image, inputs=image, outputs=label,interpretation='default').launch(debug='True')
# Out:
# Kaggle notebooks require sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://31c48d2ceac040b7a3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://31c48d2ceac040b7a3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
